# %% [markdown]
# ### Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введённой суммы (необходимо анализировать оба поля зарплаты, то есть цифра вводится одна, а запрос проверяет оба поля)

# %%
from pymongo import MongoClient
from pprint import pprint

# %%
client = MongoClient('localhost', 27017)
db = client['hh']  # hh - database
vacations = db.vacations  # vacations - collection

# %%
def find_salary(min_salary):
    expensive_vacs = vacations.find({'$or': [{'payment_min':{'$gte':min_salary}}, {'payment_max':{'$gte':min_salary}}]}).sort('payment_min')

    print('Вакансии с зарплатой выше чем ', min_salary)
    for item in expensive_vacs:
        pprint(item)

find_salary(100000)
# Out:
# Вакансии с зарплатой выше чем  100000
# {'_id': ObjectId('64b937e2bc5172a0e9da6fd6'),
#  'link': 'https://rostov.hh.ru/vacancy/82703691?from=vacancy_search_list&query=Python',
#  'name': 'Python developer (FastAPI)',
#  'payment_max': 300000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fdc'),
#  'link': 'https://rostov.hh.ru/vacancy/83645238?from=vacancy_search_list&query=Python',
#  'name': 'Middle/Senior Python-разработчик (удаленно)',
#  'payment_max': 280000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da6ffc'),
#  'link': 'https://rostov.hh.ru/vacancy/81907796?from=vacancy_search_list&query=Python',
#  'name': 'Программист Python/Go (middle) ОФИС',
#  'payment_max': 200000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9397abc5172a0e9da7020'),
#  'link': 'https://rostov.hh.ru/vacancy/83644516?from=vacancy_search_list&query=Python',
#  'name': 'Backend-разработчик Python',
#  'payment_max': 150000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9397abc5172a0e9da702b'),
#  'link': 'https://rostov.hh.ru/vacancy/82136567?from=vacancy_search_list&query=Python',
#  'name': 'Data Engineer / Программист моделей машинного обучения',
#  'payment_max': 200000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9397abc5172a0e9da7031'),
#  'link': 'https://rostov.hh.ru/vacancy/83675296?from=vacancy_search_list&query=Python',
#  'name': 'Senior Python разработчик (удаленно)',
#  'payment_max': 300000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9397bbc5172a0e9da703a'),
#  'link': 'https://rostov.hh.ru/vacancy/83456540?from=vacancy_search_list&query=Python',
#  'name': 'Team Lead Python',
#  'payment_max': 450000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93982bc5172a0e9da7091'),
#  'link': 'https://rostov.hh.ru/vacancy/82637224?from=vacancy_search_list&query=Python',
#  'name': 'Python / Django Developer',
#  'payment_max': 140000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93983bc5172a0e9da709d'),
#  'link': 'https://rostov.hh.ru/vacancy/82298693?from=vacancy_search_list&query=Python',
#  'name': 'TeamLead Python',
#  'payment_max': 200000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93984bc5172a0e9da70b7'),
#  'link': 'https://rostov.hh.ru/vacancy/83031877?from=vacancy_search_list&query=Python',
#  'name': 'Junior Python Backend',
#  'payment_max': 300000,
#  'payment_min': None,
#  'unit': '₸'}
# {'_id': ObjectId('64b93986bc5172a0e9da70c1'),
#  'link': 'https://rostov.hh.ru/vacancy/83664383?from=vacancy_search_list&query=Python',
#  'name': 'Data Scientist',
#  'payment_max': 150000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93989bc5172a0e9da70ef'),
#  'link': 'https://rostov.hh.ru/vacancy/83410038?from=vacancy_search_list&query=Python',
#  'name': 'Преподаватель IT-дисциплин C++, Python (Комендантский проспект, '
#          'Новочеркасская)',
#  'payment_max': 130000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398abc5172a0e9da70ff'),
#  'link': 'https://rostov.hh.ru/vacancy/83746382?from=vacancy_search_list&query=Python',
#  'name': 'Data инженер',
#  'payment_max': 350000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398dbc5172a0e9da7124'),
#  'link': 'https://rostov.hh.ru/vacancy/82406161?from=vacancy_search_list&query=Python',
#  'name': 'Data-engineer / Дата-инженер (Middle, Senior)',
#  'payment_max': 250000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398ebc5172a0e9da7142'),
#  'link': 'https://rostov.hh.ru/vacancy/70163749?from=vacancy_search_list&query=Python',
#  'name': 'Data Scientist (middle/senior)',
#  'payment_max': 450000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da716a'),
#  'link': 'https://rostov.hh.ru/vacancy/83303215?from=vacancy_search_list&query=Python',
#  'name': 'Преподаватель промышленного программирования',
#  'payment_max': 120000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da716b'),
#  'link': 'https://rostov.hh.ru/vacancy/83719300?from=vacancy_search_list&query=Python',
#  'name': 'DevOps Engineer (Kubernetes)',
#  'payment_max': 300000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93994bc5172a0e9da7194'),
#  'link': 'https://rostov.hh.ru/vacancy/83701313?from=vacancy_search_list&query=Python',
#  'name': 'QA Engineer (Python/JS/Selenium/Grafana/Postman/PostgreSQL/Swagger)',
#  'payment_max': 300000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93994bc5172a0e9da7197'),
#  'link': 'https://rostov.hh.ru/vacancy/82985141?from=vacancy_search_list&query=Python',
#  'name': 'Analyst / Аналитик',
#  'payment_max': 250000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93996bc5172a0e9da719d'),
#  'link': 'https://rostov.hh.ru/vacancy/82045980?from=vacancy_search_list&query=Python',
#  'name': 'Тестировщик ПО автотестирование',
#  'payment_max': 150000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93996bc5172a0e9da719f'),
#  'link': 'https://rostov.hh.ru/vacancy/82329765?from=vacancy_search_list&query=Python',
#  'name': 'Low-code developer / Разработчик',
#  'payment_max': 120000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93998bc5172a0e9da71c4'),
#  'link': 'https://rostov.hh.ru/vacancy/82535016?from=vacancy_search_list&query=Python',
#  'name': 'Инженер по внедрению телекоммуникационного биллинга (удаленно)',
#  'payment_max': 195000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93998bc5172a0e9da71cf'),
#  'link': 'https://rostov.hh.ru/vacancy/83673399?from=vacancy_search_list&query=Python',
#  'name': 'Ведущий инженер по сопровождению/DevOps/SRE',
#  'payment_max': 250000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399abc5172a0e9da71df'),
#  'link': 'https://rostov.hh.ru/vacancy/83761087?from=vacancy_search_list&query=Python',
#  'name': 'Go (Golang) Backend Developer',
#  'payment_max': 320000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399bbc5172a0e9da71f7'),
#  'link': 'https://rostov.hh.ru/vacancy/80474159?from=vacancy_search_list&query=Python',
#  'name': 'Продуктовый веб аналитик (Удаленно)',
#  'payment_max': 130000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399ebc5172a0e9da721e'),
#  'link': 'https://rostov.hh.ru/vacancy/83057174?from=vacancy_search_list&query=Python',
#  'name': 'Системный администратор Linux (удаленная работа)',
#  'payment_max': 200000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a1bc5172a0e9da724c'),
#  'link': 'https://rostov.hh.ru/vacancy/81049428?from=vacancy_search_list&query=Python',
#  'name': 'Преподаватель IT-дисциплин (Физтехпарк)',
#  'payment_max': 130000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a1bc5172a0e9da724e'),
#  'link': 'https://rostov.hh.ru/vacancy/83647053?from=vacancy_search_list&query=Python',
#  'name': 'Программист С++/Qt (junior)',
#  'payment_max': 120000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b939abbc5172a0e9da72b6'),
#  'link': 'https://rostov.hh.ru/vacancy/82329232?from=vacancy_search_list&query=Python',
#  'name': 'Сетевой инженер',
#  'payment_max': 150000,
#  'payment_min': None,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da701d'),
#  'link': 'https://rostov.hh.ru/vacancy/83630348?from=vacancy_search_list&query=Python',
#  'name': 'Преподаватель Python',
#  'payment_max': 400000,
#  'payment_min': 35000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93984bc5172a0e9da70b1'),
#  'link': 'https://rostov.hh.ru/vacancy/82820180?from=vacancy_search_list&query=Python',
#  'name': 'Python-разработчик',
#  'payment_max': 140000,
#  'payment_min': 45000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93982bc5172a0e9da708b'),
#  'link': 'https://rostov.hh.ru/vacancy/82841724?from=vacancy_search_list&query=Python',
#  'name': 'Junior/Middle backend разработчик на Fast API (Python)',
#  'payment_max': 100000,
#  'payment_min': 50000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6ff3'),
#  'link': 'https://rostov.hh.ru/vacancy/83200118?from=vacancy_search_list&query=Python',
#  'name': 'Python-разработчик',
#  'payment_max': 120000,
#  'payment_min': 60000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93986bc5172a0e9da70c8'),
#  'link': 'https://rostov.hh.ru/vacancy/83169692?from=vacancy_search_list&query=Python',
#  'name': 'Аналитик поисковых алгоритмов (SaaS, AI продукт)',
#  'payment_max': 100000,
#  'payment_min': 60000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da6fff'),
#  'link': 'https://rostov.hh.ru/vacancy/82825127?from=vacancy_search_list&query=Python',
#  'name': 'Junior/Middle Python Developer (Backend) - разработчик Питон',
#  'payment_max': 150000,
#  'payment_min': 70000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398bbc5172a0e9da711e'),
#  'link': 'https://rostov.hh.ru/vacancy/83744616?from=vacancy_search_list&query=Python',
#  'name': 'Программист - Data Scientist',
#  'payment_max': 120000,
#  'payment_min': 70000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398dbc5172a0e9da7132'),
#  'link': 'https://rostov.hh.ru/vacancy/77087257?from=vacancy_search_list&query=Python',
#  'name': 'Инженер по автоматизации / DevOps инженер',
#  'payment_max': 120000,
#  'payment_min': 70000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a6bc5172a0e9da7278'),
#  'link': 'https://rostov.hh.ru/vacancy/83581355?from=vacancy_search_list&query=Python',
#  'name': 'Программист C++',
#  'payment_max': 150000,
#  'payment_min': 70000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a6bc5172a0e9da727f'),
#  'link': 'https://rostov.hh.ru/vacancy/83016961?from=vacancy_search_list&query=Python',
#  'name': 'DevSecOps в направление разработки',
#  'payment_max': 170000,
#  'payment_min': 70000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da7013'),
#  'link': 'https://rostov.hh.ru/vacancy/82785464?from=vacancy_search_list&query=Python',
#  'name': 'Программист-аналитик по видеоанализу',
#  'payment_max': 120000,
#  'payment_min': 80000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93983bc5172a0e9da70a0'),
#  'link': 'https://rostov.hh.ru/vacancy/82264284?from=vacancy_search_list&query=Python',
#  'name': 'Руководитель группы разработки PYTHON',
#  'payment_max': 120000,
#  'payment_min': 80000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93983bc5172a0e9da70a1'),
#  'link': 'https://rostov.hh.ru/vacancy/82264281?from=vacancy_search_list&query=Python',
#  'name': 'Руководитель группы разработки PYTHON',
#  'payment_max': 120000,
#  'payment_min': 80000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93983bc5172a0e9da70a2'),
#  'link': 'https://rostov.hh.ru/vacancy/82264282?from=vacancy_search_list&query=Python',
#  'name': 'Руководитель группы разработки PYTHON',
#  'payment_max': 120000,
#  'payment_min': 80000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93984bc5172a0e9da70ab'),
#  'link': 'https://rostov.hh.ru/vacancy/82595583?from=vacancy_search_list&query=Python',
#  'name': 'Software Developer Python',
#  'payment_max': 200000,
#  'payment_min': 80000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93984bc5172a0e9da70b8'),
#  'link': 'https://rostov.hh.ru/vacancy/83055812?from=vacancy_search_list&query=Python',
#  'name': 'Junior backend-разработчик на Python',
#  'payment_max': 120000,
#  'payment_min': 80000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da715f'),
#  'link': 'https://rostov.hh.ru/vacancy/81927403?from=vacancy_search_list&query=Python',
#  'name': 'Automation QA Engineer (удаленно)',
#  'payment_max': 150000,
#  'payment_min': 80000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93998bc5172a0e9da71c6'),
#  'link': 'https://rostov.hh.ru/vacancy/83760123?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик NodeJS',
#  'payment_max': 150000,
#  'payment_min': 80000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da700b'),
#  'link': 'https://rostov.hh.ru/vacancy/82209800?from=vacancy_search_list&query=Python',
#  'name': 'Программист Python',
#  'payment_max': 110000,
#  'payment_min': 90000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9397fbc5172a0e9da706b'),
#  'link': 'https://rostov.hh.ru/vacancy/83265813?from=vacancy_search_list&query=Python',
#  'name': 'Python Developer',
#  'payment_max': 150000,
#  'payment_min': 90000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93993bc5172a0e9da7174'),
#  'link': 'https://rostov.hh.ru/vacancy/83409872?from=vacancy_search_list&query=Python',
#  'name': 'Инженер по интеграции (DevOps инженер)',
#  'payment_max': 160000,
#  'payment_min': 90000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93994bc5172a0e9da7188'),
#  'link': 'https://rostov.hh.ru/vacancy/83209482?from=vacancy_search_list&query=Python',
#  'name': 'QA Automation / Тестировщик-автоматизатор',
#  'payment_max': 120000,
#  'payment_min': 90000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a9bc5172a0e9da72ab'),
#  'link': 'https://rostov.hh.ru/vacancy/82827167?from=vacancy_search_list&query=Python',
#  'name': 'Системный администратор Linux',
#  'payment_max': 150000,
#  'payment_min': 90000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fd5'),
#  'link': 'https://rostov.hh.ru/vacancy/82972404?from=vacancy_search_list&query=Python',
#  'name': 'Python Backend разработчик',
#  'payment_max': None,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6fe5'),
#  'link': 'https://rostov.hh.ru/vacancy/81254369?from=vacancy_search_list&query=Python',
#  'name': 'Python Middle Developer',
#  'payment_max': None,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da6ff8'),
#  'link': 'https://rostov.hh.ru/vacancy/82882010?from=vacancy_search_list&query=Python',
#  'name': 'Преподаватель/ментор по программированию (Python, Roblox)',
#  'payment_max': 200000,
#  'payment_min': 100000,
#  'unit': '₸'}
# {'_id': ObjectId('64b93977bc5172a0e9da7008'),
#  'link': 'https://rostov.hh.ru/vacancy/83065458?from=vacancy_search_list&query=Python',
#  'name': 'Python разработчик fullstack',
#  'payment_max': 350000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9397ebc5172a0e9da705c'),
#  'link': 'https://rostov.hh.ru/vacancy/67635148?from=vacancy_search_list&query=Python',
#  'name': 'Python-developer',
#  'payment_max': 215000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93984bc5172a0e9da70bd'),
#  'link': 'https://rostov.hh.ru/vacancy/82904137?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python',
#  'payment_max': None,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93986bc5172a0e9da70c0'),
#  'link': 'https://rostov.hh.ru/vacancy/83344835?from=vacancy_search_list&query=Python',
#  'name': 'Data engineer',
#  'payment_max': 180000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398abc5172a0e9da7101'),
#  'link': 'https://rostov.hh.ru/vacancy/83729802?from=vacancy_search_list&query=Python',
#  'name': 'Инженер-программист',
#  'payment_max': 150000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93990bc5172a0e9da714c'),
#  'link': 'https://rostov.hh.ru/vacancy/83756975?from=vacancy_search_list&query=Python',
#  'name': 'Младший аналитик (IT)',
#  'payment_max': 140000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93990bc5172a0e9da715c'),
#  'link': 'https://rostov.hh.ru/vacancy/83232299?from=vacancy_search_list&query=Python',
#  'name': 'Инженер по тестированию',
#  'payment_max': 150000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da7164'),
#  'link': 'https://rostov.hh.ru/vacancy/81868274?from=vacancy_search_list&query=Python',
#  'name': 'Computer vision engineer (junior/middle)',
#  'payment_max': 200000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93993bc5172a0e9da7181'),
#  'link': 'https://rostov.hh.ru/vacancy/83740754?from=vacancy_search_list&query=Python',
#  'name': 'Backend разработчик',
#  'payment_max': 160000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93994bc5172a0e9da7189'),
#  'link': 'https://rostov.hh.ru/vacancy/82154578?from=vacancy_search_list&query=Python',
#  'name': 'Учитель программирования/робототехники',
#  'payment_max': None,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93998bc5172a0e9da71ce'),
#  'link': 'https://rostov.hh.ru/vacancy/82828628?from=vacancy_search_list&query=Python',
#  'name': 'Инженер-программист',
#  'payment_max': None,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93998bc5172a0e9da71d6'),
#  'link': 'https://rostov.hh.ru/vacancy/54462736?from=vacancy_search_list&query=Python',
#  'name': 'Реверс-инженер',
#  'payment_max': 160000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399abc5172a0e9da71dc'),
#  'link': 'https://rostov.hh.ru/vacancy/82126131?from=vacancy_search_list&query=Python',
#  'name': 'Web-разработчик',
#  'payment_max': 100000,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a3bc5172a0e9da724f'),
#  'link': 'https://rostov.hh.ru/vacancy/83772539?from=vacancy_search_list&query=Python',
#  'name': 'Инженер технической поддержки Linux',
#  'payment_max': None,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a3bc5172a0e9da7258'),
#  'link': 'https://rostov.hh.ru/vacancy/83673757?from=vacancy_search_list&query=Python',
#  'name': 'Системный администратор Linux',
#  'payment_max': None,
#  'payment_min': 100000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a3bc5172a0e9da7260'),
#  'link': 'https://rostov.hh.ru/vacancy/83517175?from=vacancy_search_list&query=Python',
#  'name': 'Data Scientist / Математик',
#  'payment_max': 119000,
#  'payment_min': 102000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939abbc5172a0e9da72be'),
#  'link': 'https://rostov.hh.ru/vacancy/83692035?from=vacancy_search_list&query=Python',
#  'name': 'Тестировщик',
#  'payment_max': None,
#  'payment_min': 108000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a6bc5172a0e9da7279'),
#  'link': 'https://rostov.hh.ru/vacancy/78906309?from=vacancy_search_list&query=Python',
#  'name': 'Системный администратор в компанию разработки ПО',
#  'payment_max': 160000,
#  'payment_min': 110000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6fe3'),
#  'link': 'https://rostov.hh.ru/vacancy/80505413?from=vacancy_search_list&query=Python',
#  'name': 'Программист Python',
#  'payment_max': 220000,
#  'payment_min': 115000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93997bc5172a0e9da71b9'),
#  'link': 'https://rostov.hh.ru/vacancy/83395531?from=vacancy_search_list&query=Python',
#  'name': 'Middle Automation QA Engineer',
#  'payment_max': 210000,
#  'payment_min': 115000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93982bc5172a0e9da7090'),
#  'link': 'https://rostov.hh.ru/vacancy/82676625?from=vacancy_search_list&query=Python',
#  'name': 'Бекэнд разработчик Python',
#  'payment_max': None,
#  'payment_min': 120000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93982bc5172a0e9da7096'),
#  'link': 'https://rostov.hh.ru/vacancy/81707961?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python (middle и выше)',
#  'payment_max': 300000,
#  'payment_min': 120000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93989bc5172a0e9da70f9'),
#  'link': 'https://rostov.hh.ru/vacancy/82977137?from=vacancy_search_list&query=Python',
#  'name': 'Middle Data Scientist',
#  'payment_max': 250000,
#  'payment_min': 120000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398abc5172a0e9da710c'),
#  'link': 'https://rostov.hh.ru/vacancy/82858609?from=vacancy_search_list&query=Python',
#  'name': 'DevOps-инженер',
#  'payment_max': None,
#  'payment_min': 120000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398ebc5172a0e9da7140'),
#  'link': 'https://rostov.hh.ru/vacancy/83652256?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик ML',
#  'payment_max': None,
#  'payment_min': 120000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93990bc5172a0e9da7158'),
#  'link': 'https://rostov.hh.ru/vacancy/83652274?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик ML',
#  'payment_max': None,
#  'payment_min': 120000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93996bc5172a0e9da71ae'),
#  'link': 'https://rostov.hh.ru/vacancy/82901438?from=vacancy_search_list&query=Python',
#  'name': 'Продуктовый аналитик',
#  'payment_max': 180000,
#  'payment_min': 120000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6fe7'),
#  'link': 'https://rostov.hh.ru/vacancy/80505531?from=vacancy_search_list&query=Python',
#  'name': 'Программист Python',
#  'payment_max': 220000,
#  'payment_min': 125000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fd0'),
#  'link': 'https://rostov.hh.ru/vacancy/83752469?from=vacancy_search_list&query=Python',
#  'name': 'Backend-разработчик Python/Django',
#  'payment_max': None,
#  'payment_min': 130000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fd9'),
#  'link': 'https://rostov.hh.ru/vacancy/83081327?from=vacancy_search_list&query=Python',
#  'name': 'Инженер-разработчик (CV)',
#  'payment_max': 160000,
#  'payment_min': 130000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da7005'),
#  'link': 'https://rostov.hh.ru/vacancy/83268142?from=vacancy_search_list&query=Python',
#  'name': 'Python middle developer',
#  'payment_max': 200000,
#  'payment_min': 140000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da7016'),
#  'link': 'https://rostov.hh.ru/vacancy/82204513?from=vacancy_search_list&query=Python',
#  'name': 'Python разработчик',
#  'payment_max': None,
#  'payment_min': 140000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93994bc5172a0e9da7195'),
#  'link': 'https://rostov.hh.ru/vacancy/77447194?from=vacancy_search_list&query=Python',
#  'name': 'Системный администратор Linux',
#  'payment_max': 180000,
#  'payment_min': 140000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a6bc5172a0e9da727c'),
#  'link': 'https://rostov.hh.ru/vacancy/83015449?from=vacancy_search_list&query=Python',
#  'name': 'Сетевой инженер',
#  'payment_max': None,
#  'payment_min': 140000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fcf'),
#  'link': 'https://rostov.hh.ru/vacancy/82929790?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python (Django, DRF)',
#  'payment_max': 250000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fd2'),
#  'link': 'https://rostov.hh.ru/vacancy/83756794?from=vacancy_search_list&query=Python',
#  'name': 'Middle Python Developer',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fd4'),
#  'link': 'https://rostov.hh.ru/vacancy/83359221?from=vacancy_search_list&query=Python',
#  'name': 'Python Developer',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fd8'),
#  'link': 'https://rostov.hh.ru/vacancy/75486835?from=vacancy_search_list&query=Python',
#  'name': 'Python developer',
#  'payment_max': 200000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93975bc5172a0e9da6fe2'),
#  'link': 'https://rostov.hh.ru/vacancy/83525003?from=vacancy_search_list&query=Python',
#  'name': 'Программист Python',
#  'payment_max': 260000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6fe9'),
#  'link': 'https://rostov.hh.ru/vacancy/82930139?from=vacancy_search_list&query=Python',
#  'name': 'Руководитель разработки Python',
#  'payment_max': 200000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6fec'),
#  'link': 'https://rostov.hh.ru/vacancy/80217484?from=vacancy_search_list&query=Python',
#  'name': 'Программист Python',
#  'payment_max': 200000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da7002'),
#  'link': 'https://rostov.hh.ru/vacancy/82877347?from=vacancy_search_list&query=Python',
#  'name': 'Инженер-программист (Python)',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da7004'),
#  'link': 'https://rostov.hh.ru/vacancy/78823037?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da700d'),
#  'link': 'https://rostov.hh.ru/vacancy/82877348?from=vacancy_search_list&query=Python',
#  'name': 'Инженер-программист (Python)',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9397abc5172a0e9da7021'),
#  'link': 'https://rostov.hh.ru/vacancy/83616575?from=vacancy_search_list&query=Python',
#  'name': 'Python разработчик|Python developer Middle| Middle+ (удаленно)',
#  'payment_max': 170000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93982bc5172a0e9da7084'),
#  'link': 'https://rostov.hh.ru/vacancy/82848370?from=vacancy_search_list&query=Python',
#  'name': 'Teamlead backend разработчик на Fast API (Python)',
#  'payment_max': 200000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93984bc5172a0e9da70bc'),
#  'link': 'https://rostov.hh.ru/vacancy/82986443?from=vacancy_search_list&query=Python',
#  'name': 'Middle Python Developer',
#  'payment_max': 250000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93986bc5172a0e9da70c5'),
#  'link': 'https://rostov.hh.ru/vacancy/83773323?from=vacancy_search_list&query=Python',
#  'name': 'Middle backend разработчик (Python)',
#  'payment_max': 200000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93990bc5172a0e9da7159'),
#  'link': 'https://rostov.hh.ru/vacancy/81004020?from=vacancy_search_list&query=Python',
#  'name': 'Программист-разработчик',
#  'payment_max': 300000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da7161'),
#  'link': 'https://rostov.hh.ru/vacancy/82256056?from=vacancy_search_list&query=Python',
#  'name': 'Системный инженер / Linux инженер / DevOps',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da7170'),
#  'link': 'https://rostov.hh.ru/vacancy/81290745?from=vacancy_search_list&query=Python',
#  'name': 'QA-automation',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93996bc5172a0e9da719c'),
#  'link': 'https://rostov.hh.ru/vacancy/82551665?from=vacancy_search_list&query=Python',
#  'name': 'DevOps инженер',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93996bc5172a0e9da71a4'),
#  'link': 'https://rostov.hh.ru/vacancy/82988114?from=vacancy_search_list&query=Python',
#  'name': 'QA-automation Middle',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93998bc5172a0e9da71c9'),
#  'link': 'https://rostov.hh.ru/vacancy/81874007?from=vacancy_search_list&query=Python',
#  'name': 'Data Engineer',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399bbc5172a0e9da71fe'),
#  'link': 'https://rostov.hh.ru/vacancy/83684240?from=vacancy_search_list&query=Python',
#  'name': 'Data Engineer (ОФИС)',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399dbc5172a0e9da7212'),
#  'link': 'https://rostov.hh.ru/vacancy/83739228?from=vacancy_search_list&query=Python',
#  'name': 'DevOps Engineer',
#  'payment_max': 300000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a1bc5172a0e9da7247'),
#  'link': 'https://rostov.hh.ru/vacancy/82551803?from=vacancy_search_list&query=Python',
#  'name': 'Администратор баз данных / DBA',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a4bc5172a0e9da726d'),
#  'link': 'https://rostov.hh.ru/vacancy/83575602?from=vacancy_search_list&query=Python',
#  'name': 'QA Automation Engineer',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a8bc5172a0e9da729b'),
#  'link': 'https://rostov.hh.ru/vacancy/77912433?from=vacancy_search_list&query=Python',
#  'name': 'Аналитик данных',
#  'payment_max': None,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a9bc5172a0e9da72aa'),
#  'link': 'https://rostov.hh.ru/vacancy/75486720?from=vacancy_search_list&query=Python',
#  'name': 'DevOps инженер (сопровождение шины данных)',
#  'payment_max': 180000,
#  'payment_min': 150000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fcc'),
#  'link': 'https://rostov.hh.ru/vacancy/83458412?from=vacancy_search_list&query=Python',
#  'name': 'Middle Python (Django) Developer',
#  'payment_max': None,
#  'payment_min': 160000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6ff6'),
#  'link': 'https://rostov.hh.ru/vacancy/82987526?from=vacancy_search_list&query=Python',
#  'name': 'Старший Python разработчик',
#  'payment_max': 250000,
#  'payment_min': 160000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9397bbc5172a0e9da7038'),
#  'link': 'https://rostov.hh.ru/vacancy/83264671?from=vacancy_search_list&query=Python',
#  'name': 'Python-программист, микросервисная архитектура, Senior',
#  'payment_max': None,
#  'payment_min': 160000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399bbc5172a0e9da71ef'),
#  'link': 'https://rostov.hh.ru/vacancy/71825078?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик баз данных (PostgreSQL)',
#  'payment_max': 160000,
#  'payment_min': 160000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a4bc5172a0e9da7263'),
#  'link': 'https://rostov.hh.ru/vacancy/83743681?from=vacancy_search_list&query=Python',
#  'name': 'Программист встраиваемых систем',
#  'payment_max': None,
#  'payment_min': 160000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fcd'),
#  'link': 'https://rostov.hh.ru/vacancy/82417354?from=vacancy_search_list&query=Python',
#  'name': 'Python разработчик',
#  'payment_max': 265000,
#  'payment_min': 170000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398dbc5172a0e9da712f'),
#  'link': 'https://rostov.hh.ru/vacancy/82257729?from=vacancy_search_list&query=Python',
#  'name': 'DevOps-инженер',
#  'payment_max': 200000,
#  'payment_min': 170000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da7160'),
#  'link': 'https://rostov.hh.ru/vacancy/77911825?from=vacancy_search_list&query=Python',
#  'name': 'Системный администратор/DevOps (Linux)',
#  'payment_max': None,
#  'payment_min': 170000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fdf'),
#  'link': 'https://rostov.hh.ru/vacancy/82826027?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python (FastAPI, MySQL, Clickhouse) удаленно',
#  'payment_max': 270000,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6fe6'),
#  'link': 'https://rostov.hh.ru/vacancy/83452764?from=vacancy_search_list&query=Python',
#  'name': 'Python-разработчик',
#  'payment_max': 240000,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6fee'),
#  'link': 'https://rostov.hh.ru/vacancy/81489621?from=vacancy_search_list&query=Python',
#  'name': 'Data Scientist / ML Engineer (Middle+)',
#  'payment_max': 260000,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6ff1'),
#  'link': 'https://rostov.hh.ru/vacancy/82299017?from=vacancy_search_list&query=Python',
#  'name': 'Python разработчик/программист (Middle Python Developer)',
#  'payment_max': None,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6ff4'),
#  'link': 'https://rostov.hh.ru/vacancy/81489620?from=vacancy_search_list&query=Python',
#  'name': 'Data Scientist / ML Engineer (Middle+)',
#  'payment_max': 260000,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da6ffe'),
#  'link': 'https://rostov.hh.ru/vacancy/82299184?from=vacancy_search_list&query=Python',
#  'name': 'Программист Python (Банк)',
#  'payment_max': 320000,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da7010'),
#  'link': 'https://rostov.hh.ru/vacancy/81054303?from=vacancy_search_list&query=Python',
#  'name': 'Python разработчик (middle+)',
#  'payment_max': 220000,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93996bc5172a0e9da71a7'),
#  'link': 'https://rostov.hh.ru/vacancy/80292094?from=vacancy_search_list&query=Python',
#  'name': 'Marketing Analyst',
#  'payment_max': None,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93998bc5172a0e9da71c8'),
#  'link': 'https://rostov.hh.ru/vacancy/82357302?from=vacancy_search_list&query=Python',
#  'name': 'Middle Системный администратор Linux (ubuntu)/Devops',
#  'payment_max': 250000,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399bbc5172a0e9da71f0'),
#  'link': 'https://rostov.hh.ru/vacancy/82257004?from=vacancy_search_list&query=Python',
#  'name': 'Инженер по автоматизированному тестированию',
#  'payment_max': None,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a9bc5172a0e9da72a1'),
#  'link': 'https://rostov.hh.ru/vacancy/82419588?from=vacancy_search_list&query=Python',
#  'name': 'Linux engineers/ SRE (Kubernetes)',
#  'payment_max': 230000,
#  'payment_min': 180000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fd7'),
#  'link': 'https://rostov.hh.ru/vacancy/82039217?from=vacancy_search_list&query=Python',
#  'name': 'Python разработчик (удалённо)',
#  'payment_max': 280000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fdb'),
#  'link': 'https://rostov.hh.ru/vacancy/83574305?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик backend Python, Middle',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6fe8'),
#  'link': 'https://rostov.hh.ru/vacancy/83161563?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python, удаленно',
#  'payment_max': 350000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6ff0'),
#  'link': 'https://rostov.hh.ru/vacancy/83267180?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python (FastAPI)',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da700e'),
#  'link': 'https://rostov.hh.ru/vacancy/83045032?from=vacancy_search_list&query=Python',
#  'name': 'Backend - разработчик Python (Middle+)',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da7011'),
#  'link': 'https://rostov.hh.ru/vacancy/83045033?from=vacancy_search_list&query=Python',
#  'name': 'Backend - разработчик Python (Middle+)',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da7018'),
#  'link': 'https://rostov.hh.ru/vacancy/82661632?from=vacancy_search_list&query=Python',
#  'name': 'Backend - разработчик Python (Middle+)',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398abc5172a0e9da70fc'),
#  'link': 'https://rostov.hh.ru/vacancy/83648180?from=vacancy_search_list&query=Python',
#  'name': 'Backend разработчик Middle +, Senior (Python)',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398abc5172a0e9da7100'),
#  'link': 'https://rostov.hh.ru/vacancy/81489493?from=vacancy_search_list&query=Python',
#  'name': 'MLOps/ML engineer (Middle+)',
#  'payment_max': 280000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398abc5172a0e9da7102'),
#  'link': 'https://rostov.hh.ru/vacancy/80002041?from=vacancy_search_list&query=Python',
#  'name': 'Старший программист-разработчик (Python/Django) / Senior back-end '
#          'developer',
#  'payment_max': 300000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398abc5172a0e9da7105'),
#  'link': 'https://rostov.hh.ru/vacancy/81489494?from=vacancy_search_list&query=Python',
#  'name': 'MLOps/ML engineer (Middle+)',
#  'payment_max': 280000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398abc5172a0e9da710b'),
#  'link': 'https://rostov.hh.ru/vacancy/82596122?from=vacancy_search_list&query=Python',
#  'name': 'Старший разработчик Perl',
#  'payment_max': 300000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398bbc5172a0e9da7112'),
#  'link': 'https://rostov.hh.ru/vacancy/80840681?from=vacancy_search_list&query=Python',
#  'name': 'PostgreSQL Senior Developer',
#  'payment_max': 400000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398bbc5172a0e9da7122'),
#  'link': 'https://rostov.hh.ru/vacancy/83079653?from=vacancy_search_list&query=Python',
#  'name': 'Преподаватель программирования для детей и подростков',
#  'payment_max': 300000,
#  'payment_min': 200000,
#  'unit': '₸'}
# {'_id': ObjectId('64b9398dbc5172a0e9da7134'),
#  'link': 'https://rostov.hh.ru/vacancy/83350665?from=vacancy_search_list&query=Python',
#  'name': 'Преподаватель программирования для детей и подростков',
#  'payment_max': 350000,
#  'payment_min': 200000,
#  'unit': '₸'}
# {'_id': ObjectId('64b9398ebc5172a0e9da713d'),
#  'link': 'https://rostov.hh.ru/vacancy/83509718?from=vacancy_search_list&query=Python',
#  'name': 'DevOps Engineer',
#  'payment_max': 400000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da7165'),
#  'link': 'https://rostov.hh.ru/vacancy/82932448?from=vacancy_search_list&query=Python',
#  'name': 'Программист-разработчик',
#  'payment_max': 500000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93992bc5172a0e9da7169'),
#  'link': 'https://rostov.hh.ru/vacancy/83158404?from=vacancy_search_list&query=Python',
#  'name': 'SRE / DevOps engineer',
#  'payment_max': 400000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93993bc5172a0e9da7176'),
#  'link': 'https://rostov.hh.ru/vacancy/83564650?from=vacancy_search_list&query=Python',
#  'name': 'ML-инженер / CV',
#  'payment_max': 300000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93994bc5172a0e9da7187'),
#  'link': 'https://rostov.hh.ru/vacancy/83662799?from=vacancy_search_list&query=Python',
#  'name': 'DevOps инженер',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399abc5172a0e9da71d7'),
#  'link': 'https://rostov.hh.ru/vacancy/83759671?from=vacancy_search_list&query=Python',
#  'name': 'DevOps',
#  'payment_max': 350000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399dbc5172a0e9da720b'),
#  'link': 'https://rostov.hh.ru/vacancy/80645110?from=vacancy_search_list&query=Python',
#  'name': 'Продуктовый аналитик в команду «Метамодель»',
#  'payment_max': 300000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399ebc5172a0e9da7214'),
#  'link': 'https://rostov.hh.ru/vacancy/83385496?from=vacancy_search_list&query=Python',
#  'name': 'Embeded Программист/разработчик БПЛА (Беспилотных летательных '
#          'аппаратов)',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a3bc5172a0e9da7256'),
#  'link': 'https://rostov.hh.ru/vacancy/81801981?from=vacancy_search_list&query=Python',
#  'name': 'Senior Go Developer',
#  'payment_max': 500000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a4bc5172a0e9da7276'),
#  'link': 'https://rostov.hh.ru/vacancy/83336330?from=vacancy_search_list&query=Python',
#  'name': 'Middle DevOps-инженер (удаленно)',
#  'payment_max': 230000,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a9bc5172a0e9da72a9'),
#  'link': 'https://rostov.hh.ru/vacancy/82012718?from=vacancy_search_list&query=Python',
#  'name': 'Эксперт базы знаний (пентестер)',
#  'payment_max': None,
#  'payment_min': 200000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fde'),
#  'link': 'https://rostov.hh.ru/vacancy/83748034?from=vacancy_search_list&query=Python',
#  'name': 'Ведущий Python-developer',
#  'payment_max': 340000,
#  'payment_min': 220000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398dbc5172a0e9da712a'),
#  'link': 'https://rostov.hh.ru/vacancy/82431339?from=vacancy_search_list&query=Python',
#  'name': 'Продуктовый аналитик/ data analyst',
#  'payment_max': 240000,
#  'payment_min': 220000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93976bc5172a0e9da6feb'),
#  'link': 'https://rostov.hh.ru/vacancy/79824429?from=vacancy_search_list&query=Python',
#  'name': 'Python-разработчик (Django)',
#  'payment_max': None,
#  'payment_min': 230000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da6ff7'),
#  'link': 'https://rostov.hh.ru/vacancy/83112341?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python',
#  'payment_max': 310000,
#  'payment_min': 230000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a1bc5172a0e9da7248'),
#  'link': 'https://rostov.hh.ru/vacancy/83760556?from=vacancy_search_list&query=Python',
#  'name': 'Инженер Сопровождения Платформы',
#  'payment_max': None,
#  'payment_min': 230000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da700c'),
#  'link': 'https://rostov.hh.ru/vacancy/82926114?from=vacancy_search_list&query=Python',
#  'name': 'Python разработчик (аккредитованная компания)',
#  'payment_max': 270000,
#  'payment_min': 240000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399abc5172a0e9da71e0'),
#  'link': 'https://rostov.hh.ru/vacancy/82902035?from=vacancy_search_list&query=Python',
#  'name': 'Data Engineer',
#  'payment_max': None,
#  'payment_min': 240000,
#  'unit': '₽'}
# {'_id': ObjectId('64b937e2bc5172a0e9da6fdd'),
#  'link': 'https://rostov.hh.ru/vacancy/83461035?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик Python/Developer Python',
#  'payment_max': 400000,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93982bc5172a0e9da7085'),
#  'link': 'https://rostov.hh.ru/vacancy/81085097?from=vacancy_search_list&query=Python',
#  'name': 'Python-разработчик Senior',
#  'payment_max': None,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93987bc5172a0e9da70d6'),
#  'link': 'https://rostov.hh.ru/vacancy/83633568?from=vacancy_search_list&query=Python',
#  'name': 'Data Engineer',
#  'payment_max': None,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9398dbc5172a0e9da7125'),
#  'link': 'https://rostov.hh.ru/vacancy/83542479?from=vacancy_search_list&query=Python',
#  'name': 'Программист',
#  'payment_max': None,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93996bc5172a0e9da71a2'),
#  'link': 'https://rostov.hh.ru/vacancy/83672056?from=vacancy_search_list&query=Python',
#  'name': 'Middle / Senior DevOps engineer',
#  'payment_max': 400000,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93997bc5172a0e9da71bc'),
#  'link': 'https://rostov.hh.ru/vacancy/83704441?from=vacancy_search_list&query=Python',
#  'name': 'Go Tech/Team Lead',
#  'payment_max': 300000,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399abc5172a0e9da71dd'),
#  'link': 'https://rostov.hh.ru/vacancy/82252801?from=vacancy_search_list&query=Python',
#  'name': 'Ведущий Web-аналитик',
#  'payment_max': None,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399abc5172a0e9da71e6'),
#  'link': 'https://rostov.hh.ru/vacancy/83428612?from=vacancy_search_list&query=Python',
#  'name': 'Ведущий разработчик беспилотных систем',
#  'payment_max': None,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a4bc5172a0e9da7270'),
#  'link': 'https://rostov.hh.ru/vacancy/82385518?from=vacancy_search_list&query=Python',
#  'name': 'Fullstack Бағдарламашы (программист оқытушы)',
#  'payment_max': 350000,
#  'payment_min': 250000,
#  'unit': '₸'}
# {'_id': ObjectId('64b939a9bc5172a0e9da72ae'),
#  'link': 'https://rostov.hh.ru/vacancy/82653589?from=vacancy_search_list&query=Python',
#  'name': 'Head of DS',
#  'payment_max': None,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939acbc5172a0e9da72ca'),
#  'link': 'https://rostov.hh.ru/vacancy/83576648?from=vacancy_search_list&query=Python',
#  'name': 'Аналитик трафика',
#  'payment_max': None,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939acbc5172a0e9da72d6'),
#  'link': 'https://rostov.hh.ru/vacancy/83748839?from=vacancy_search_list&query=Python',
#  'name': 'Разработчик С/С++',
#  'payment_max': None,
#  'payment_min': 250000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a3bc5172a0e9da7257'),
#  'link': 'https://rostov.hh.ru/vacancy/80485582?from=vacancy_search_list&query=Python',
#  'name': 'Devops / SRE инженер (офис)',
#  'payment_max': 315000,
#  'payment_min': 260000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93977bc5172a0e9da7001'),
#  'link': 'https://rostov.hh.ru/vacancy/83242182?from=vacancy_search_list&query=Python',
#  'name': 'Ведущий разработчик Python (FastAPI)',
#  'payment_max': None,
#  'payment_min': 280000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93979bc5172a0e9da700f'),
#  'link': 'https://rostov.hh.ru/vacancy/82508298?from=vacancy_search_list&query=Python',
#  'name': 'Python backend разработчик',
#  'payment_max': 500000,
#  'payment_min': 300000,
#  'unit': '₸'}
# {'_id': ObjectId('64b9398dbc5172a0e9da7136'),
#  'link': 'https://rostov.hh.ru/vacancy/80871654?from=vacancy_search_list&query=Python',
#  'name': 'Data Analyst (senior)',
#  'payment_max': None,
#  'payment_min': 300000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a8bc5172a0e9da7298'),
#  'link': 'https://rostov.hh.ru/vacancy/83450677?from=vacancy_search_list&query=Python',
#  'name': 'Senior Python Developer ML',
#  'payment_max': 350000,
#  'payment_min': 300000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939abbc5172a0e9da72c2'),
#  'link': 'https://rostov.hh.ru/vacancy/83713600?from=vacancy_search_list&query=Python',
#  'name': 'Senior MLOps-инженер',
#  'payment_max': 450000,
#  'payment_min': 300000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a6bc5172a0e9da7277'),
#  'link': 'https://rostov.hh.ru/vacancy/83659335?from=vacancy_search_list&query=Python',
#  'name': 'Ведущий разработчик бэк-энда (NodeJS)',
#  'payment_max': 350000,
#  'payment_min': 350000,
#  'unit': '₽'}
# {'_id': ObjectId('64b939a8bc5172a0e9da7291'),
#  'link': 'https://rostov.hh.ru/vacancy/83635533?from=vacancy_search_list&query=Python',
#  'name': 'Senior Linux developer',
#  'payment_max': None,
#  'payment_min': 350000,
#  'unit': '₽'}
# {'_id': ObjectId('64b9399dbc5172a0e9da720f'),
#  'link': 'https://rostov.hh.ru/vacancy/83037197?from=vacancy_search_list&query=Python',
#  'name': 'Site Reliability Engineer (SRE) / DevOps',
#  'payment_max': 400000,
#  'payment_min': 370000,
#  'unit': '₽'}
# {'_id': ObjectId('64b93990bc5172a0e9da714e'),
#  'link': 'https://rostov.hh.ru/vacancy/82493110?from=vacancy_search_list&query=Python',
#  'name': 'Linux-DevOps инженер',
#  'payment_max': None,
#  'payment_min': 800000,
#  'unit': '₸'}
# {'_id': ObjectId('64b93979bc5172a0e9da7017'),
#  'link': 'https://rostov.hh.ru/vacancy/82714337?from=vacancy_search_list&query=Python',
#  'name': 'Senior Python разработчик',
#  'payment_max': 1400000,
#  'payment_min': 1000000,
#  'unit': '₸'}
# {'_id': ObjectId('64b93979bc5172a0e9da7014'),
#  'link': 'https://rostov.hh.ru/vacancy/83084250?from=vacancy_search_list&query=Python',
#  'name': 'Преподаватель по Python',
#  'payment_max': 6000000,
#  'payment_min': 2000000,
#  'unit': 'm'}
