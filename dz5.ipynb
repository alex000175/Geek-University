# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
# from selenium.webdriver.support.ui import Select
from pprint import pprint
from pymongo import MongoClient
import time

# %%
# Подготовим базу данных
client = MongoClient('localhost', 27017)
db = client['letters']  # hh - database
letters = db.letters  # items - collection

# функция добавления данных в БД
def add_data_to_db(doc, only_new = True):
    exists = letters.find_one({'link': doc['link']})
    if only_new == True:
        if not exists:
            try:
                letters.insert_one(doc)
            except DuplicateKeyError:
                pass
    else:
        try:
            letters.insert_one(doc)
        except DuplicateKeyError:
            pass

# %%
s = Service('chromedriver')
chromeOptions = Options()
chromeOptions.add_argument('start-maximized')

drv = webdriver.Chrome(service=s, options=chromeOptions)
drv.implicitly_wait(0.2)
drv.get("https://account.mail.ru")

# авторизация
time.sleep(1)
elem = drv.find_element(By.NAME, 'username')
elem.send_keys("study.ai_172@mail.ru")
elem.send_keys(Keys.ENTER)

time.sleep(1)
elem = drv.find_element(By.NAME, 'password')
elem.send_keys("NextPassword172#")
elem.send_keys(Keys.ENTER)
time.sleep(1)

# %%
lettes_count_text = drv.find_element(By.XPATH, "//a[contains(@class,'nav__item')]").get_attribute('title')
res = (lettes_count_text.split(',')[1])
lettes_count = int(''.join(filter(lambda i: i.isdigit(), res)))
print(f'Всего писем в папке <Входящие>: {lettes_count}')
# Out:
# 1032

# %%
# сбор данных

# создаю и заполняю пустое множество для ссылок на письма
links = set() 
mails = drv.find_elements(By.CLASS_NAME, "js-letter-list-item")
link = mails[0].get_attribute('href')

while True:
    if len(links) >= lettes_count: # == lettes_count
        break
    
    mails = drv.find_elements(By.CLASS_NAME, "js-letter-list-item")
    for mail in mails:
        link = (mail.get_attribute('href'))
        links.add(link)

    action = ActionChains(drv)
    action.move_to_element(mails[-1])
    action.perform()

# %%
# заполняю БД данными
for link in links:
    info = {}
    drv.get(link)
    time.sleep(1) 
    # скорость соединения подводит, пришлось обернуть все вот в такой цикл
    num_retries = 0
    for i in range(1, num_retries+1):
        try:
            info['date'] = drv.find_element(By.XPATH, "//div[@class='letter__date']").text.split(',')[0]
            info['from_email'] = info['from_email'] = drv.find_element(By.XPATH, "//span[contains(@class, 'letter-contact')]").get_attribute('title')
            info['author'] = drv.find_element(By.XPATH, "//span[contains(@class,'letter-contact')]").text
            info['subject'] = drv.find_element(By.XPATH, "//h2[@class='thread-subject']").text
            info['body'] = drv.find_element(By.XPATH, "//div[@class='letter__body']").text
            info['link'] = link
            add_data_to_db(info)
            break
        except:
            time.sleep(1)
            num_retries += 1



drv.close()

# %%
# Проверяем, что данные в БД
for item in letters.find({}):
    pprint(item)
# Out:
# {'_id': ObjectId('64c4d00e66d75d88661359b1'),
#  'author': 'Sidebar',
#  'body': 'Email not displaying properly? View browser version.\n'
#          'APRIL 5 2023\n'
#          'Unpredictable Black Boxes are Terrible Interfaces\n'
#          'magrawala.substack.com\n'
#          'Why generative AI tools can be so difficult to use and how we might '
#          'improve them.\n'
#          'AI UI UX\n'
#          'Credit: Maneesh Agrawala\n'
#          '2023 Beer & Beverage Branding Trends Review\n'
#          'cododesign.com\n'
#          'The beer industry has been on its heels since early 2020, and this '
#          'year is shaping up to be another challenging one.\n'
#          'Branding Trends\n'
#          'Credit: CODO Design\n'
#          'Fresh Fonts\n'
#          'freshfonts.io\n'
#          'All the best new indie fonts in your inbox, handpicked by curators.\n'
#          'Inspiration Typography Resources\n'
#          'Credit: Fresh Fonts\n'
#          'The world’s most satisfying toggle\n'
#          'svarden.se\n'
#          'Adding playfulness to a UI with physics by creating a skeuomorphic '
#          'pull cord dark mode toggle using Verlet integration.\n'
#          'Animation Experiment UX\n'
#          'Credit: Jonathan Svärdén\n'
#          'Accessibility for designer: where do I start?\n'
#          'stephaniewalter.design\n'
#          'A big list of resources, articles, blog posts, and checklists to '
#          'help you, designers, get started on your “building more accessible '
#          'products” journey.\n'
#          'Accessibility Resources\n'
#          'Credit: Stef Walter\n'
#          '  You’re receiving this email because you signed up on sidebar.io. '
#          'Unsubscribe\n'
#          'Sacha Greif - Kyoto, Japan',
#  'date': '5 апреля',
#  'from_email': 'noreply@sidebar.io',
#  'link': 'https://e.mail.ru/inbox/0:16806822760881325451:0/?afterReload=1',
#  'subject': 'Christoph Niemann, Copilot, Wikimedia Grid, html review, Grid '
#             'World'}
# {'_id': ObjectId('64c4d03166d75d88661359b2'),
#  'author': 'Mail.ru',
#  'body': '        Вход с нового устройства в аккаунт\n'
#          ' study.ai_172@mail.ru \n'
#          '      В аккаунт study.ai_172@mail.ru вошли с нового устройства.\n'
#          '  Если вы этого не делали, измените пароль, чтобы обезопасить '
#          'аккаунт.\n'
#          '  Время 3 октября, 00:54\n'
#          '  Устройство Microsoft Windows 10, Google Chrome 106, Соединенные '
#          'Штаты Америки\n'
#          '  Посмотреть список устройств\n'
#          '  Узнайте, как защитить аккаунт, на нашем сайте по безопасности.\n'
#          '    Вы получили это письмо, потому что являетесь пользователем '
#          'Mail\u200c.ru на основании Пользовательского соглашения.\n'
#          '  Copyright 2022 VK, Москва — Все права защищены.\n'
#          '  Служба поддержки      Mail ID\n'
#          '   ',
#  'date': '3 октября 2022',
#  'from_email': 'security@id.mail.ru',
#  'link': 'https://e.mail.ru/inbox/0:16647476841217183121:0/?afterReload=1',
#  'subject': 'Вход с нового устройства в аккаунт'}
# {'_id': ObjectId('64c4d03466d75d88661359b3'),
#  'author': 'METRO',
#  'body': 'Все акции\n'
#          'Онлайн-каталог\n'
#          '👉 Все щедрые скидки\n'
#          '\n'
#          'Каталог\n'
#          'METRO\n'
#          '02.02.2023 - 15.02.2023\n'
#          '\n'
#          'Алкогольные\n'
#          'предложения\n'
#          '02.02.2023 - 15.02.2023\n'
#          '      Горячая линия METRO\n'
#          '8-800-700-10-77\n'
#          'пн-пт: с 07:00 до 22:00\n'
#          'сб-вс: с 08:00 до 22:00\n'
#          '  Вы получили это письмо, потому что подписаны на рассылку от Metro '
#          'Cash & Carry Russia на адрес. Вы можете изменить настройки рассылки '
#          'в личном кабинете. По всем вопросам обращайтесь на горячую линию '
#          'METRO. Если вы не хотите более получать электронные рассылки от '
#          'METRO, то нажмите на ссылку: отказаться от рассылки\n'
#          '\n'
#          '\n'
#          'Наличие товаров ограничено запасами в торговом центре МЕТРО Кэш энд '
#          'Керри. Товары, подлежащие обязательной сертификации, '
#          'сертифицированы. Цены указаны в рублях с НДС с учётом скидки и '
#          'действительны на моментотправкиписьма. Изображение товаров может '
#          'отличаться от фактического изображения. ООО «МЕТРО Кэш энд Керри» '
#          'вправе изменить цену товара без предварительного уведомления. Скидка '
#          'не распространяется на товары, участвующиевдействующих каталогах '
#          'МЕТРО. В случае если на товар действует иное специальное '
#          'предложение, скидки не суммируются.\n'
#          '\n'
#          'Размер «старой» цены на товар определяется исходя из цены на товар, '
#          'действовавшей на 04.01.2023 как минимум в одном ТЦ среди торговых '
#          'центров ООО «МЕТРО Кэш энд Керри». Размер «старой» цены может '
#          'отличаться в вашем торговом центре METRO.\n'
#          '\n'
#          '\n'
#          'Веб-версия',
#  'date': '10 февраля',
#  'from_email': 'metronews@newsletter.metro-cc.ru',
#  'link': 'https://e.mail.ru/inbox/0:16760346911260186543:0/?afterReload=1',
#  'subject': '❤️ Подарки для любимых!'}
# {'_id': ObjectId('64c4d05e66d75d88661359b4'),
#  'author': 'Mail.ru',
#  'body': '        Изменён пароль в аккаунте\n'
#          ' study.ai_172@mail.ru \n'
#          '      В аккаунте study.ai_172@mail.ru изменили пароль.\n'
#          '  Если вы этого не делали, восстановите доступ.\n'
#          '  Узнайте, как защитить аккаунт, на нашем сайте по безопасности.\n'
#          '    Вы получили это письмо, потому что являетесь пользователем '
#          'Mail\u200c.ru на основании Пользовательского соглашения.\n'
#          '  Copyright 2023 VK, Москва — Все права защищены.\n'
#          '  Служба поддержки       Mail ID\n'
#          '   ',
#  'date': '16 января',
#  'from_email': 'security@id.mail.ru',
#  'link': 'https://e.mail.ru/inbox/0:16738904521407715015:0/?afterReload=1',
#  'subject': 'Изменён пароль в аккаунте'}
# {'_id': ObjectId('64c4d06266d75d88661359b5'),
#  'author': 'METRO',
#  'body': 'Все акции\n'
#          'Онлайн-каталог\n'
#          'Уважаемый Геннадий Павлович,\n'
#          '\n'
#          'Специально для вас мы подготовили персональные купоны на популярные '
#          'категории товаров. Воспользуйтесь скидкой в период с 12 января по 8 '
#          'февраля 2023 года.\n'
#          '\n'
#          'Обратите, пожалуйста, внимание:\n'
#          '1. Купоны действительны только при покупке по карте клиента '
#          '3360018213001 и могут быть использованы лишь один раз\n'
#          '2. Максимальная сумма скидки по купону – 1000 рублей.\n'
#          '3. Скидка не распространяется на товары, участвующие в промо-акциях\n'
#          '4. При наличии многоуровневого ценника скидка применяется '
#          'относительно цены первого уровня.\n'
#          '\n'
#          'Если вы столкнулись с проблемой считывания штрих-кода на кассе, '
#          'рекомендуем просканировать штрих-код из приложения METRO.\n'
#          'Период действия купонов: c 12.01 по 08.02.2023 г.\n'
#          'Распечатать купоны\n'
#          'или покажите письмо с телефона\n'
#          '        Горячая линия METRO\n'
#          '8-800-700-10-77\n'
#          'пн-пт: с 07:00 до 22:00\n'
#          'сб-вс: с 08:00 до 22:00\n'
#          '                Вы получили это письмо, потому что подписаны на '
#          'рассылку от Metro Cash&Carry Russia на адрес STUDY.AI_172@MAIL.RU. '
#          'По всем вопросам обращайтесь на горячую линию METRO. Если вы не '
#          'хотите более получать электронные рассылки от METRO, то нажмите '
#          'отказаться от рассылки.\n'
#          '        Условия предоставления скидки по купонам:\n'
#          '1. Скидка предоставляется для держателя карты 3360018213001.\n'
#          '2. Предложение действительно с 12 января по 8 февраля 2023 г. при '
#          'совершении покупки в торговом центре ООО «МЕТРО Кэш энд Керри» и не '
#          'действует при приобретении товаров по договору доставки.\n'
#          '3. Скидка не распространяется на товары, участвующие в действующих '
#          'каталогах МЕТРО, а также на товары категории «Всегда нужно», товары '
#          'отделов «Оптовый алкоголь». В случае многоуровневого ценника на '
#          'товар, скидка применяется к цене первого уровня. В случае если на '
#          'товар действует иное специальное предложение, скидки не '
#          'суммируются.\n'
#          '4. Использовать соответствующий купон на товар или группу товаров '
#          'можно не более одного раза в период действия предложения.\n'
#          '5. Максимальная сумма скидки – 1000 рублей.\n'
#          '6. Ассортимент категорий, на которые действует предложение, можно '
#          'уточнить по телефону горячей линии: 8 800 700 10 77. Время работы '
#          'горячей линии: в будние дни 7.00 – 22.00, в выходные дни 8.00 – '
#          '22.00 по московскому времени.\n'
#          '7. При возврате товара, купленного с использованием купона, купон '
#          'считается реализованным, его повторная выдача не производится.\n'
#          '8. Условием предоставления скидки является предъявление данного '
#          'купона в распечатанном или электронном виде на кассе до «закрытия» '
#          'накладной.\n'
#          '9. При выборе расчета на кассе по форме оплаты «Предоплата» купон не '
#          'может быть использован.\n'
#          '10. Предложение действительно при наличии товара в торговом центре.\n'
#          '11. В случае если цена алкогольной продукции со скидкой ниже '
#          'минимальной цены, установленной законом, товар продается по '
#          'установленной законом цене.\n'
#          '                Веб-версия\n'
#          '     ',
#  'date': '11 января',
#  'from_email': 'metronews@newsletter.metro-cc.ru',
#  'link': 'https://e.mail.ru/inbox/0:16734419210365215431:0/?afterReload=1',
#  'subject': 'Персональные предложения на популярные товары!'}
# {'_id': ObjectId('64c4d06766d75d88661359b6'),
#  'author': 'GeekBrains',
#  'body': '24 января\n'
#          'Как стать специалистом, который зарабатывает 1000 долларов в день\n'
#          'Компании по всему миру тестируют новые технологии и внедряют их в '
#          'свои проекты. Это приносит бизнесу много денег, а спрос на инновации '
#          'растет. \n'
#          '\n'
#          'Большинство новых технологий находятся на очень ранней стадии '
#          'развития, а бизнесу уже сейчас нужны специалисты, которые могут '
#          'работать с блокчейном, большими данными и метавселенными. '
#          'Профессионалы могут зарабатывать 1000 долларов в день!\n'
#          'Как начать карьеру в этой отрасли, расскажем на интенсиве «Путь в '
#          'ИТ. Новое время», который пройдет 24 января в 18:00 МСК.\n'
#          'Участвовать бесплатно!\n'
#          '6 новых технологий, которые разберем на интенсиве\n'
#          'Data science и big data\n'
#          'Big data — данные больших объемов и различных форматов. Data science '
#          '— наука, которая занимается сбором, обработкой и анализом этих '
#          'данных.\n'
#          'Блокчейн\n'
#          'Технология баз данных нового поколения. Она лежит в основе надежного '
#          'хранения и обмена цифровыми активами: деньгами, произведениями '
#          'искусства и важной информацией.\n'
#          'Метавселенная\n'
#          'Виртуальный мир, в котором пользователи будут работать, учиться, '
#          'отдыхать, развлекаться, общаться и даже покупать недвижимость. Все '
#          'как в реальности.\n'
#          'Web 3.0\n'
#          'Это интернет будущего. Он станет независимым от компаний, а '
#          'пользователи — полноправными владельцами своих данных.\n'
#          'Нейронные сети\n'
#          'Программный код, который имитирует работу мозга и способен к '
#          'самообучению.\n'
#          'Квантовый компьютер\n'
#          'Это новый класс компьютеров, которые используют явления квантовой '
#          'механики. Пока квантовый компьютер — гипотетическое устройство, но '
#          'ученые уже разрабатывают для него платформы и ПО.\n'
#          'Узнать про технологии\n'
#          'Не нужно быть гением\n'
#          'Чтобы работать с новыми технологиями\n'
#          '\n'
#          'Освоить профессию можно за пару лет, а зарабатывать первые деньги — '
#          'уже через несколько месяцев. Подробно об этом расскажем на '
#          'онлайн-интенсиве «Путь в ИТ. Новое время».\n'
#          '\n'
#          'Что еще вас ждет:\n'
#          '\n'
#          '— разберетесь с ключевыми технологиями, которые прямо сейчас меняют '
#          'мир;\n'
#          '— начнете понимать сложные технические термины; \n'
#          '— узнаете правду о популярных профессиях;\n'
#          '— поймете, что действительно ждет ИT-индустрию и всех нас в '
#          'ближайшие 10 лет.\n'
#          'Еще на интенсиве мы разыграем бесплатные программы обучения в '
#          'GeekBrains на 1 000 000 рублей.\n'
#          'Зарегистрироваться\n'
#          'Кому будет полезен интенсив\n'
#          '1\n'
#          'Всем, кто интересуется новыми технологиями.\n'
#          '2\n'
#          'Новичкам, которым интересны популярные направления в IT.\n'
#          '3\n'
#          'Людям, которые знакомы с IT, но не погружались в новые и сложные '
#          'темы.\n'
#          'Будем все объяснять максимально просто и доступно, с примерами и '
#          'интересными кейсами!\n'
#          'Участвовать бесплатно\n'
#          'Мы в социальных сетях\n'
#          'Свяжитесь с нами\n'
#          'sales@geekbrains.ru\n'
#          '8-800-700-68-41\n'
#          'Полезные ссылки\n'
#          'Бесплатные вебинары\n'
#          'Обучающие курсы\n'
#          'Тесты\n'
#          'Наш блог\n'
#          'Истории студентов\n'
#          'Вы получили это письмо, так как являетесь пользователем портала '
#          'GeekBrains. Если вы не хотите получать рассылку, вы можете '
#          'отписаться или настроить параметры\n'
#          'Если письмо отображается некорректно или вы хотите им поделиться, '
#          'жмите сюда.\n'
#          'Общество с ограниченной ответственностью «ГикБреинс». ОГРН: '
#          '1167746654569. Юридический адрес: 125167, г. Москва, Ленинградский '
#          'пр-кт, д. 39 стр. 79, этаж, помещение, часть комнаты 23, XXXIV, 1. '
#          'Телефон 8-800-700-68-41.',
#  'date': '19 января',
#  'from_email': 'noreply@e.geekbrains.ru',
#  'link': 'https://e.mail.ru/inbox/0:16741078851256363366:0/?afterReload=1',
#  'subject': '🤔 Как зарабатывать 1000$ в день'}
# {'_id': ObjectId('64c4d06b66d75d88661359b7'),
#  'author': 'Sidebar',
#  'body': 'Email not displaying properly? View browser version.\n'
#          'DECEMBER 14 2022\n'
#          'Holiday Snowtacular 2022\n'
#          'lu.ma\n'
#          'Join us for a holiday fundraiser live stream with 12 wonderful '
#          'guests, each discussing a different topic!\n'
#          'CSS\n'
#          'Credit: 🐴 Frontend Horse - Holiday Snowtacular ❄️\n'
#          'Optimizing Web Fonts in Next.js 13\n'
#          'lydiahallie.io\n'
#          'An awesome visual deep dive into font layout shifts, and CSS '
#          'properties to prevent them.\n'
#          'CSS React\n'
#          'Credit: Lydia Hallie ✨\n'
#          'Midjourney vs. human illustrators: has AI already won?\n'
#          'evilmartians.com\n'
#          'An experiment: we repeatedly give a typical work task to both a '
#          'human artist and a text-to-image AI art generator. Who wins?\n'
#          'Illustration Trends\n'
#          'Credit: Evil Martians\n'
#          'How Apple and Google Are Taking Over the In-Car User Experience\n'
#          'theturnsignalblog.com\n'
#          'Will the future in-car interaction be CarPlay and Android Auto or a '
#          'native system?\n'
#          'UX\n'
#          'Credit: Casper Kessels\n'
#          'Does Your Product Actually Need Dark Mode?\n'
#          'commandbar.com\n'
#          'Some things to consider before going over to the dark side, and '
#          'adding dark mode to your product.\n'
#          'Dark Mode\n'
#          'Credit: Cristina Bunea\n'
#          '  You’re receiving this email because you signed up on sidebar.io. '
#          'Unsubscribe\n'
#          'Sacha Greif - Kyoto, Japan',
#  'date': '14 декабря 2022',
#  'from_email': 'noreply@sidebar.io',
#  'link': 'https://e.mail.ru/inbox/0:16710090971519235656:0/?afterReload=1',
#  'subject': 'Holiday Snowtacular, Web Fonts, Midjourney vs. Illustrators, '
#             'In-Car UX, Dark Mode'}
# {'_id': ObjectId('64c4d06f66d75d88661359b8'),
#  'author': 'Screenlane',
#  'body': 'IKEA iOS app\n'
#          'TweetSharePin\n'
#          'Wonder iOS app\n'
#          'TweetSharePin\n'
#          "This week's links 🔗\n"
#          "The Smartest Website You Haven't Heard of\n"
#          'lessons in UI design from an industrial supply company.\n'
#          'The Web is Good Now\n'
#          'There are quite a few things in the world of web design and '
#          'development that have gotten… easy. It might be time to take a look '
#          'at how you’re approaching some of the building blocks of your '
#          'website...\n'
#          'Finding your T-Shape as a Generalist Designer\n'
#          '“So, what kind of designer are you?” It’s a question all designers '
#          'will encounter during their careers\n'
#          'Braun font\n'
#          'A new typeface for Braun\n'
#          'The 2022 Web Almanac\n'
#          'The Web Almanac is an annual state of the web report combining the '
#          'expertise of the web community with the data and trends of the HTTP '
#          'Archive.\n'
#          'A details element as a burger menu is not accessible\n'
#          'Using the native HTML disclosure widget for a burger menu is so '
#          'enticing. Unfortunately, the details/summary elements come with '
#          "accessibility issues, so it's not an inclusive solution.\n"
#          'Product designers, meet your new friend, HCI\n'
#          "If you haven't met, I want to introduce you to a field of study that "
#          "many designers may not know well. Product Designers, I'd like to "
#          'introduce you to HCI.\n'
#          "Submit products or links you want to see featured in next week's "
#          'email here (or just reply to this email)\n'
#          'If you have feedback or want to chat, let me know.\n'
#          'Have a great week!\n'
#          'Ramy\n'
#          "You're getting this email because you subscribed at screenlane.com "
#          '(formerly UI Movement).\n'
#          'Click here to unsubscribe\n'
#          'Rocket Gems LTD, Lytchett House, 13 Freeland Park, Wareham Road, '
#          'Poole, Dorset, BH16 6FA, United Kingdom',
#  'date': '30 сентября 2022',
#  'from_email': 'ramy@screenlane.com',
#  'link': 'https://e.mail.ru/inbox/0:16645438871459604712:0/?afterReload=1',
#  'subject': 'IKEA & Wonder screens'}
# {'_id': ObjectId('64c4d07466d75d88661359b9'),
#  'author': 'GeekBrains',
#  'body': 'Программы со скидкой\n'
#          'Выход на новую работу: как быстро добиться успеха\n'
#          '⏳ Время чтения: 15 минут\n'
#          'Читать\n'
#          'Не повышают зарплату, скучно\n'
#          'и все надоело?\n'
#          'Кажется, кто-то ступил на опасную тропу профессионального '
#          'выгорания.\n'
#          'Сегодня поговорим, как понять, что пора прощаться с прежней работой '
#          'и искать что-то новенькое.\n'
#          'В статье уже поделились, как побороть страх в первый рабочий день и '
#          'быстрее адаптироваться в новом коллективе.\n'
#          'Подборка с советами, гайды и немного мотивации по ссылке ниже 👇\n'
#          'Читать статью\n'
#          '5 признаков, что пора менять работу\n'
#          'Чаще всего поводами для ухода с прежней компании становятся '
#          'следующие факторы:\n'
#          '1. Скука\n'
#          'На работе вы больше листаете ленту ВКонтакте или залипаете на '
#          'YouTube. В этом офисе вы только растрачиваете свое время.\n'
#          'Уровень токсичности: 5 баллов\n'
#          '2. Нет ощущения важности своего труда\n'
#          'Компания сама по себе, вы сами по себе. Руководство не замечает '
#          'ваших усилий и вам непонятно, ценят ли ваш труд.\n'
#          'Уровень токсичности: 7 баллов\n'
#          '3. Работа занимает все время\n'
#          'Тратите часы на дорогу в офис и обратно, часто задерживаетесь после '
#          'рабочего дня, берете задачи на дом и работаете в выходные.\n'
#          'Уровень токсичности: 8 баллов\n'
#          '4. Негативная рабочая среда\n'
#          'Коллеги постоянно раздражают, а руководитель недоволен всем вокруг. '
#          'Такое окружение вызывает апатию и равнодушие.\n'
#          'Уровень токсичности: 10 баллов\n'
#          '5. Работа вредит здоровью\n'
#          'Вы работаете так много, что у вас нет времени заниматься спортом, '
#          'хорошо питаться или спать.\n'
#          'Уровень токсичности: 10 баллов\n'
#          'Что еще можно почитать в блоге GeekBrains\n'
#          'Лучшие нейросети, к которым стоит присмотреться\n'
#          'Что такое нейросеть и какие задачи она может выполнять.\n'
#          'Читать статью\n'
#          'Входит ли учеба в трудовой стаж: насколько это выгодно\n'
#          'Какие проблемы здесь скрыты и насколько целесообразно это делать.\n'
#          'Читать статью\n'
#          'Цвета брендов: разбираемся в психологии цвета\n'
#          'На какие критерии следует опираться и какие сервисы могут в этом '
#          'помочь.\n'
#          'Читать статью\n'
#          'Мы в социальных сетях\n'
#          'Свяжитесь с нами\n'
#          'support@geekbrains.ru\n'
#          '8-800-700-68-41\n'
#          'Полезные ссылки\n'
#          'Бесплатные мероприятия\n'
#          'Обучающие программы\n'
#          'Тест «Кто ты в IT?»\n'
#          'Наш блог\n'
#          'Истории студентов\n'
#          'Вы получили это письмо, так как являетесь пользователем портала '
#          'GeekBrains. Если вы не хотите получать рассылку, вы можете '
#          'отписаться\n'
#          'Общество с ограниченной ответственностью «ГикБреинс». ОГРН: '
#          '1167746654569. Юридический адрес: 125167, г. Москва, Ленинградский '
#          'пр-кт, д. 39 стр. 79, этаж, помещение, часть комнаты 23, XXXIV, 1. '
#          'Телефон 8-800-700-68-41.',
#  'date': '18 марта',
#  'from_email': 'noreply@e.geekbrains.ru',
#  'link': 'https://e.mail.ru/inbox/0:16791217862054035415:0/?afterReload=1',
#  'subject': '⚠️ Опасная зона'}
# {'_id': ObjectId('64c4d07766d75d88661359ba'),
#  'author': 'Mail.ru',
#  'body': '        Вход с нового устройства в аккаунт\n'
#          ' study.ai_172@mail.ru \n'
#          '      В аккаунт study.ai_172@mail.ru вошли с нового устройства.\n'
#          '  Если вы этого не делали, измените пароль, чтобы обезопасить '
#          'аккаунт.\n'
#          '  Время 21 июня, 20:35\n'
#          '  Устройство Microsoft Windows 10, Яндекс.Браузер 23, '
#          'Санкт-Петербург, Россия\n'
#          '  Посмотреть список устройств\n'
#          '  Узнайте, как защитить аккаунт, на нашем сайте по безопасности.\n'
#          '    Вы получили это письмо, потому что являетесь пользователем '
#          'Mail\u200c.ru на основании Пользовательского соглашения.\n'
#          '  Copyright 2023 VK, Москва — Все права защищены.\n'
#          '  Служба поддержки      Mail ID\n'
#          '   ',
#  'date': '21 июня',
#  'from_email': 'security@id.mail.ru',
#  'link': 'https://e.mail.ru/inbox/0:16873689111647383188:0/?afterReload=1',
#  'subject': 'Вход с нового устройства в аккаунт'}
# {'_id': ObjectId('64c4d07d66d75d88661359bb'),
#  'author': 'METRO',
#  'body': 'Все акции\n'
#          'Онлайн-каталог\n'
#          '👉 Все щедрые скидки\n'
#          'Семга филе-кусок Балтийский берег слабосоленая, 200г 659 479,20₽\n'
#          'Шашлык Мираторг из мраморной говядины, 800г 849 649 ₽\n'
#          'Кетчуп Heinz томатный, 800г 289 199 ₽\n'
#          'Мороженое Monterra\n'
#          'в ассортименте 519 309 ₽\n'
#          'Таблетки для посудомоечной машины Finish All In One бесфосфатные, '
#          '100шт 2809 1199 ₽\n'
#          'Указаны цены, действующие в торговых центрах METRO.\n'
#          'Ассортимент и стоимость товаров уточняйте в Вашем торговом центре '
#          'METRO или по телефону горячей линии.\n'
#          '👉 Смотреть каталог\n'
#          '\n'
#          'Каталог\n'
#          'METRO\n'
#          '20.07.2023 - 02.08.2023\n'
#          '\n'
#          'Ассортимент\n'
#          'для баров и кафе\n'
#          '25.05.2023 - 31.08.2023\n'
#          '      Горячая линия METRO\n'
#          '8-800-700-10-77\n'
#          'пн-пт: с 07:00 до 22:00\n'
#          'сб-вс: с 08:00 до 22:00\n'
#          '  Вы получили это письмо, потому что подписаны на рассылку от Metro '
#          'Cash & Carry Russia на адрес. Вы можете изменить настройки рассылки '
#          'в личном кабинете. По всем вопросам обращайтесь на горячую линию '
#          'METRO. Если вы не хотите более получать электронные рассылки от '
#          'METRO, то нажмите на ссылку: отказаться от рассылки\n'
#          '\n'
#          '\n'
#          'ТОВАРНОЕ ПРЕДЛОЖЕНИЕ ДЕЙСТВУЕТ С 06.07 ПО 19.07. ПО ДАННЫМ '
#          'ВНУТРЕННЕГО МОНИТОРИНГА ЦЕН, ПРОВЕДЁННОГО METRO С 23.06 ПО '
#          '25.06.2023. СРЕДИ МАГАЗИНОВ ДРУГИХ СЕТЕЙ И ПЛОЩАДОК ИСХОДЯ ИЗ УРОВНЯ '
#          'ЗНАНИЯ ОБЩЕДОСТУПНЫХ ЦЕН НА ТОВАР (ВЫБОРКА ИЗ 149 РЕСПОНДЕНТОВ СРЕДИ '
#          'МАГАЗИНОВ И ОНЛАЙН ПЛАТФОРМ) В ЦЕНТРАЛЬНОМ, СЕВЕРО-ЗАПАДНОМ, '
#          'СИБИРСКОМ, ЮЖНОМ, УРАЛЬСКОМ И ПРИВОЛЖСКОМ ФЕДЕРАЛЬНЫХ ОКРУГАХ. '
#          'АССОРТИМЕНТ И КОЛИЧЕСТВО ТОВАРОВ АКЦИИ ОГРАНИЧЕНЫ. ЦЕНА В РУБЛЯХ С '
#          'НДС. НА ЦЕНУ ТОВАРА НЕ ДЕЙСТВУЮТ ДРУГИЕ СКИДКИ И СПЕЦ.ПРЕДЛОЖЕНИЯ. '
#          'ООО «МЕТРО КЭШ ЭНД КЕРРИ» ВПРАВЕ ИЗМЕНИТЬ УСЛОВИЯ ИЛИ ОТМЕНИТЬ '
#          'ПРОВЕДЕНИЕ АКЦИИ. ПОДРОБНОСТИ УТОЧНЯЙТЕ В ВАШЕМ ТЦ МЕТRO. ВРЕМЯ '
#          'ПРОДАЖИ АЛКОГОЛЬНОЙ ПРОДУКЦИИ ОПРЕДЕЛЯЕТСЯ ДЕЙСТВУЮЩИМ '
#          'ЗАКОНОДАТЕЛЬСТВОМ.\n'
#          '\n'
#          'Реклама. ООО «МЕТРО Кэш энд Керри», ОГРН 102770027214\n'
#          '\n'
#          'Наличие товаров ограничено запасами в торговом центре МЕТРО Кэш энд '
#          'Керри. Товары, подлежащие обязательной сертификации, '
#          'сертифицированы. Цены указаны в рублях с НДС с учётом скидки и '
#          'действительны на моментотправкиписьма. Изображение товаров может '
#          'отличаться от фактического изображения. ООО «МЕТРО Кэш энд Керри» '
#          'вправе изменить цену товара без предварительного уведомления. Скидка '
#          'не распространяется на товары, участвующиевдействующих каталогах '
#          'МЕТРО. В случае если на товар действует иное специальное '
#          'предложение, скидки не суммируются.\n'
#          '\n'
#          'Размер «старой» цены на товар определяется исходя из цены на товар, '
#          'действовавшей на 01.07.2023 как минимум в одном ТЦ среди торговых '
#          'центров ООО «МЕТРО Кэш энд Керри». Размер «старой» цены может '
#          'отличаться в вашем торговом центре METRO.\n'
#          '\n'
#          'Веб-версия',
#  'date': '20 июля',
#  'from_email': 'metronews@newsletter.metro-cc.ru',
#  'link': 'https://e.mail.ru/inbox/0:16898604930512348996:0/?afterReload=1',
#  'subject': '🎉 Никаких компромиссов во время выходных!'}
# {'_id': ObjectId('64c4d08166d75d88661359bc'),
#  'author': 'Webdesigner News',
#  'body': 'Submit Story\n'
#          'UX Podcasts For Designers\n'
#          'Podcasts are a fantastic opportunity to get up close with the people '
#          'who know their craft. In this post, we compiled podcasts that are '
#          'bound to provide valuable insights into UX and new perspectives on '
#          'the field. Perfect for a short coffee break or a long commute.\n'
#          'How Pinterest’s design systems team measures adoption\n'
#          'Identifying good metrics for Pinterest’s design system, Gestalt, is '
#          'no different. It’s hugely important for our team to know how much '
#          'value we’re providing, and for our leadership to understand whether '
#          'the investment is paying off.\n'
#          'ChatGPT on track to surpass 100 million users faster than TikTok or '
#          'Instagram\n'
#          'ChatGPT, the AI chatbot that’s garnered widespread attention since '
#          'its launch two months ago, is on track to surpass 100 million '
#          'monthly active users (MAUs), according to data compiled by UBS.\n'
#          'Experience Design — What is it and How Does it Relate to UX?\n'
#          'Experience design is a fast-growing design discipline focused on '
#          'creating meaningful experiences. Experience designers use an '
#          'interdisciplinary approach combining design, psychology, and '
#          'technology to develop user-centered digital products.\n'
#          'The Guide To Responsive Design In 2023 and Beyond\n'
#          'The term “responsive” means a lot of things now. We have media '
#          'queries that check for user preferences, and modern CSS features '
#          'that help us make a fluid layout without even using a media query. '
#          'Responsive is different nowadays. It’s an exciting time, indeed!\n'
#          'See all the latest stories\n'
#          'Home\n'
#          'About us\n'
#          'Disclaimer\n'
#          'Privacy Policy\n'
#          'Advertising\n'
#          'Submit Story\n'
#          'Contact\n'
#          'Home\n'
#          'About us\n'
#          'Disclaimer\n'
#          'Privacy Policy\n'
#          'Advertising\n'
#          'Submit Story\n'
#          'Contact\n'
#          '© 2022 - All Rights Reserved\n'
#          'Click here to unsubscribe',
#  'date': '4 февраля',
#  'from_email': 'no-reply@webdesignernews.com',
#  'link': 'https://e.mail.ru/inbox/0:16755156570917263476:0/?afterReload=1',
#  'subject': 'Latest stories'}
# {'_id': ObjectId('64c4d1f466d75d88661359bd'),
#  'author': 'METRO',
#  'body': 'Все акции\n'
#          'Онлайн-каталог\n'
#          '👉 Все щедрые скидки\n'
#          '👉 Получить кэшбэк\n'
#          '\n'
#          'Каталог\n'
#          'METRO\n'
#          '19.01.2023 - 01.02.2023\n'
#          '\n'
#          'Алкогольные\n'
#          'предложения\n'
#          '19.01.2023 - 01.02.2023\n'
#          '      Горячая линия METRO\n'
#          '8-800-700-10-77\n'
#          'пн-пт: с 07:00 до 22:00\n'
#          'сб-вс: с 08:00 до 22:00\n'
#          '  Вы получили это письмо, потому что подписаны на рассылку от Metro '
#          'Cash & Carry Russia на адрес. Вы можете изменить настройки рассылки '
#          'в личном кабинете. По всем вопросам обращайтесь на горячую линию '
#          'METRO. Если вы не хотите более получать электронные рассылки от '
#          'METRO, то нажмите на ссылку: отказаться от рассылки\n'
#          '\n'
#          '\n'
#          'Скидка -20% на тихие вина\n'
#          '1. Предложение действительно с 27 января по 30 января 2023 года '
#          'включительно при совершении покупки в торговом центре ООО «МЕТРО Кэш '
#          'энд Керри», а также при оформлении самовывоза на сайте '
#          'https://online.metro-cc.ru и из мобильного приложения.\n'
#          '2. Предложение распространяется на тихие вина. Скидка не '
#          'распространяется на товары, участвующие в действующих каталогах '
#          'МЕТРО, товары категории «Лови выгоду» и товары отделов «Оптовый '
#          'алкоголь. В случае многоуровневого ценника на товар, скидка '
#          'применяется к цене первого уровня. В случае если на товар действует '
#          'иное специальное предложение, скидки не суммируются.\n'
#          '3. Использовать соответствующий купон на товар или группу товаров '
#          'можно не более одного раза в период действия предложения.\n'
#          '4. Максимальная сумма скидки по купону – 1000 рублей.\n'
#          '5. Подробную информацию можно уточнить по телефону горячей линии: 8 '
#          '800 700 10 77. Время работы горячей линии: в будние дни 7.00 – '
#          '22.00, в выходные дни 8.00 – 22.00 по московскому времени.\n'
#          '6. При возврате товара, купленного с использованием купона, купон '
#          'считается реализованным, его повторная выдача не производится.\n'
#          '7. Условием предоставления скидки является предъявление данного '
#          'купона в распечатанном или электронном виде на кассе до «закрытия» '
#          'накладной.\n'
#          '8. При выборе расчета на кассе по форме оплаты «Предоплата» купон не '
#          'может быть использован.\n'
#          '\n'
#          'Наличие товаров ограничено запасами в торговом центре МЕТРО Кэш энд '
#          'Керри. Товары, подлежащие обязательной сертификации, '
#          'сертифицированы. Цены указаны в рублях с НДС с учётом скидки и '
#          'действительны на моментотправкиписьма. Изображение товаров может '
#          'отличаться от фактического изображения. ООО «МЕТРО Кэш энд Керри» '
#          'вправе изменить цену товара без предварительного уведомления. Скидка '
#          'не распространяется на товары, участвующиевдействующих каталогах '
#          'МЕТРО. В случае если на товар действует иное специальное '
#          'предложение, скидки не суммируются.\n'
#          '\n'
#          'Размер «старой» цены на товар определяется исходя из цены на товар, '
#          'действовавшей на 04.01.2023 как минимум в одном ТЦ среди торговых '
#          'центров ООО «МЕТРО Кэш энд Керри». Размер «старой» цены может '
#          'отличаться в вашем торговом центре METRO.\n'
#          '\n'
#          'Щедрые выходные c 26 по 29 января 2023\n'
#          '\n'
#          '*Для выборочного ассортимента при накоплении максимального '
#          'количества наклеек, 1 шт. акционного товара пробивается в чеке за 1 '
#          'руб. Акция «Метрополия» действует во всех ТЦ ООО «МЕТРО Кэш энд '
#          'Керри», кроме г. Вологды, и только для держателей карт клиента или '
#          'гостя МЕТRО, 18+. Выдача наклеек от 500 р. с НДС в чеке за покупки в '
#          'ТЦ в период с 08.12.2022 по 30.03.2023. Обмен наклеек на кухонные '
#          'ножи VIVO в ТЦ METRO со скидкой до 99,9% в период с 08.12.2022 по '
#          '13.04.2023г.\n'
#          '\n'
#          'Товары отделов «Оптовый алкоголь» и «Табак», подарочные карты METRO, '
#          'расчеты по форме оплаты «Предоплата» в Акции не участвуют. '
#          'Максимальное количество бумажных наклеек к выдаче : 30 шт. в день на '
#          'одного клиента, электронных наклеек – 60 шт. (30 за покупку (от 15 '
#          '000 рублей с НДС) и 30 наклеек экстра начислений за товары партнеров '
#          'и собственные бренды). С порядком начисления можно ознакомиться в '
#          'правилах Акции. Количество акционных товаров ограничено, внешний вид '
#          'товара может отличаться от представленного в рекламном материале. '
#          'Наклейки могут быть бумажные и электронные. Электронные наклейки и '
#          'наклейки, полученные в ТЦ, накапливаются раздельно, их объединение '
#          'или участие двумя способами не допускается.\n'
#          '\n'
#          'Выдача бумажных наклеек доступна с 08.12.2022. Начисление '
#          'электронных наклеек доступно с 28.12.2022.В период накопления '
#          'электронных наклеек могут проходить акции с экстраначислением: при '
#          'покупке товаров собственных торговых марок** METRO и товаров '
#          'партнеров (такие товары будут отмечены специальным стикером на '
#          'полках в ТЦ и онлайн-витринах) электронные наклейки начисляются в '
#          'двойном размере.\n'
#          '\n'
#          'Приветственные 20 электронных наклеек за регистрацию доступны в '
#          'период с 28.12.2022 по 31.01.2023.Организатор вправе досрочно '
#          'изменить условия или завершить проведение Акции по своему усмотрению '
#          'в одностороннем порядке. Полные правила и условия участия см. на '
#          'сайте metropoliya.metro-cc.ru.\n'
#          '\n'
#          'ДОСТАВКУ И ПРОДАЖУ ТОВАРОВ ОСУЩЕСТВЛЯЮТ:\n'
#          'ООО «МЕТРО КЭШ ЭНД КЕРРИ», АДРЕС: 125445, Г. МОСКВА, ЛЕНИНГРАДСКОЕ '
#          'ШОССЕ, 71Г, ОГРН: 1027700272148;\n'
#          'ООО «ИНСТАМАРТ СЕРВИС», АДРЕС: 115035, Г. МОСКВА, ВН.ТЕР.Г. '
#          'МУНИЦИПАЛЬНЫЙ ОКРУГ ЗАМОСКВОРЕЧЬЕ, УЛ. САДОВНИЧЕСКАЯ, Д. 9А, ЭТАЖ 5, '
#          'ПОМЕЩ. I, КОМ. 1. ОГРН: 1187746494980.\n'
#          '** Собственная торговая марка – товары и услуги, производимые '
#          'сторонним производителем под заказ владельца марки и продаваемые под '
#          'одним из брендов владельца марки: METRO Chef, METRO Professional, '
#          'METRO Premium, Rioba, Fine life, Aro, Sigma, Tarrington house, '
#          'H-line.\n'
#          '\n'
#          '1 «Гарантия низких цен» — название Акции. На товары Акции действует '
#          'низкая или снижена регулярная цена по сравнению с ценой на них в '
#          'METRO на 22.06.2022 г. Подробности см.на сайте '
#          'guarantee.metro-cc.ru.\n'
#          '\n'
#          '2 Срок действия Акции - с 23.06.2022 по 31.12.2022 во всех ТЦ METRO '
#          'ООО «МЕТРО Кэш энд Керри». Возвращается десятикратная стоимостная '
#          'разница между превышающей по стоимости ценой покупки участвующего в '
#          'Акции товара METRO по сравнению с ценой такого товара в других '
#          'магазинах (перечень магазинов ограничен) в виде кэшбэк-баллов на '
#          'карту METRO. 1 балл = 1 рубль. В Акции участвует ограниченный '
#          'ассортимент товаров только с регулярной ценой. Для участия '
#          'необходимо подать заявку (вкл. информацию о товаре из другого '
#          'магазина - цене, упаковке, дате проверки цены и т.д.) и подписаться '
#          'на новости / акции METRO. Информация об организаторе, акционном '
#          'ассортименте, магазинах-участниках, правилах участия и другие '
#          'подробности см. на guarantee.metro-cc.ru.\n'
#          '\n'
#          'Максимальная сумма начисления кэшбэк-баллов за 1 календ. месяц — '
#          '10000 баллов по одной карте клиента. Акционные баллы начисляются не '
#          'более чем за 6 (шесть) единиц одного и того же артикула в рамках '
#          'одной покупки (одного кассового чека). Организатор вправе по своему '
#          'усмотрению продлить или иным образом изменить срок проведения '
#          'Акции.\n'
#          '\n'
#          '* По данным исследования «МАСМИ» в марте 2022 года исходя из уровня '
#          'предпочтения выбора МЕТRО как магазина с наиболее выгодными оптовыми '
#          'ценами, который подходит как для покупок для себя (для дома), так и '
#          'для бизнеса. Выборка из 2000 респондентов, совершивших как минимум '
#          'одну покупку в МЕТRО за предшествовавшие исследованию 12 месяцев, в '
#          'Центральном, Северо-Западном, Сибирском, Южном, Уральском, '
#          'Приволжском ФО, г. Москве. Оптовая цена — цена при покупке товара в '
#          'больших упаковках, в бóльшем количестве (несколько единиц одного '
#          'товара).\n'
#          '\n'
#          'Веб-версия',
#  'date': '27 января',
#  'from_email': 'metronews@newsletter.metro-cc.ru',
#  'link': 'https://e.mail.ru/inbox/0:16748100640695946142:0/?afterReload=1',
#  'subject': 'Скидка -20% на тихие вина и другие щедрые предложения!'}
# {'_id': ObjectId('64c4d1f866d75d88661359be'),
#  'author': 'Sidebar',
#  'body': 'Email not displaying properly? View browser version.\n'
#          'FEBRUARY 6 2023\n'
#          'The users Netflix forgot about\n'
#          'uxdesign.cc\n'
#          'Netflix’s new password sharing policies seem to only consider a few '
#          'use cases. This is why building personas is important.\n'
#          'UX\n'
#          'Credit: UX Collective\n'
#          'CSS color-mix()\n'
#          'developer.chrome.com\n'
#          'Mix colors, in any of the supported color spaces, right from your '
#          'CSS.\n'
#          'CSS Color Theory\n'
#          'Credit: Chrome Developers\n'
#          'Poline: esoteric color palette generator\n'
#          'meodai.github.io\n'
#          'Poline draws lines between anchors over polar coordinates to '
#          'generate pleasing color palettes.\n'
#          'Color Theory Resources\n'
#          'Credit: David Aerne\n'
#          'WhatsApp\n'
#          'koto.studio\n'
#          'WhatsApp redesign case study by Koto Studio.\n'
#          'Case Study\n'
#          'Credit: Koto\n'
#          'TresJS: The solution for 3D on VueJS\n'
#          'tresjs.org\n'
#          'Declarative ThreeJS using Vue Components\n'
#          'JavaScript\n'
#          'Credit: Alvaro Sabu\n'
#          '  You’re receiving this email because you signed up on sidebar.io. '
#          'Unsubscribe\n'
#          'Sacha Greif - Kyoto, Japan',
#  'date': '6 февраля',
#  'from_email': 'noreply@sidebar.io',
#  'link': 'https://e.mail.ru/inbox/0:16756746931046311673:0/?afterReload=1',
#  'subject': 'Netflix Users, color-mix(), Poline, WhatsApp, TresJS'}

# %%
# # Несколько вкладок   
# driver = new ChromeDriver();
# driver.manage().window().maximize();
        
# String baseUrl = "http://www.google.co.uk/";
# driver.get(baseUrl);
# driver.findElement(By.cssSelector("body")).sendKeys(Keys.CONTROL +"t");

# ArrayList<String> tabs = new ArrayList<String> (driver.getWindowHandles());
# driver.switchTo().window(tabs.get(1)); //switches to new tab
# driver.get("https://www.facebook.com");

# driver.switchTo().window(tabs.get(0)); // switch back to main screen        
# driver.get("https://www.news.google.com");
